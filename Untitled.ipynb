# %%
import numpy as np
import pandas as pd

# %%
products = pd.read_csv('wc-product-export-22-11-2023-1700682750584.csv')

# %%
products
# Out:
#        ID       Type  SKU                                 Name Published  \
# 0     305   variable  NaN           Sabba Orthopaedic Mattress         1
# 1     450  variation  NaN  Sabba Orthopaedic Mattress - Single         1
# 2     451  variation  NaN  Sabba Orthopaedic Mattress - Double         1
# 3     455   variable  NaN                      Oxford Mattress         1
# 4     459  variation  NaN             Oxford Mattress - Single         1
# ..    ...        ...  ...                                  ...       ...
# 596  4122     simple  NaN              Verona 3 Seater Sofabed         1
# 597  4124     simple  NaN             Balmour 3 Seater Sofabed         1
# 598  4126     simple  NaN                      Windsor Sofabed         1
# 599  4128     simple  NaN                  Jamie 2 Seater Grey         1
# 600  4130     simple  NaN            Jamie 2 Seater Orange Tan         1
#
#      Is featured? Visibility in catalogue  Short description  \
# ...

# %%
import pymongo
import json

data_to_insert = products.to_dict(orient='records')

client = pymongo.MongoClient("mongodb+srv://wasimibkhan:09uG5h4iqGYSOnpi@cluster0.txfwy7a.mongodb.net/?retryWrites=true&w=majority")
db = client["sabba-furniture"]
collection = db.products  

collection.insert_many(data_to_insert)

client.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 data_to_insert = products.to_dict(orient='records')
#       6 client = pymongo.MongoClient("mongodb+srv://wasimibkhan:09uG5h4iqGYSOnpi@cluster0.txfwy7a.mongodb.net/?retryWrites=true&w=majority")
# ----> 7 db = client.sabba-furniture
#       8 collection = db.products
#      10 collection.insert_many(data_to_insert)
#
# NameError: name 'furniture' is not defined
